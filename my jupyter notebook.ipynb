# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <H2>OJOBO O EMMANUEL</H2>
#      i am a computer engineer

# %% [markdown]
# <i>i am interested in data science because it makes me understand and solve a problem from an analytic perspective with out sentiment</i>

# %% [markdown]
# <h3>i want to create a program that combines two list using the zip function</h3>

# %%
list1 = ["john", "mike", "jimmy", "frank"]
list2 = ["alex", "emmy", "peter", "adams"]
result = list(zip(list1,list2))
print(result)
# Out:
# [('john', 'alex'), ('mike', 'emmy'), ('jimmy', 'peter'), ('frank', 'adams')]

# %% [markdown]
# |Horizontal rule |Bulleted list|Numbered list|Table|
# |----------------|-------------|-------------|-----|
# |  stil          |render       |nice         |value|
# |    1           |   2         | 3           |  4  |
#
# ***
#
# * Jimmy
# * Frank
# * Leo
#
# 1. jimmy
# 2. frank
# 3. Leo
# ***
# <a href = "https: //google.com"> Google page</a>
